# %%
import pandas as pd
import os
import spacy
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
from nltk import pos_tag
from gensim import matutils,corpora, models
from sklearn import cross_validation
from sklearn.grid_search import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %% [markdown]
# # We have positive reviews and negative reviews in separate directories

# %%
negative_list = os.listdir("negative_reviews") # names of all files in the negative_polarity dir into a list
positive_list = os.listdir("positive_reviews") # names of all files in the positive_polarity dir into a list

# %%
def preprocess(files_list,root_dir,polarity):
    labeled_class = []
    reviews = []
    actual_class =[]
    for j in files_list:
        labeled_class.append(polarity)
        k = str(open( root_dir + '/' + j).read())
        reviews.append(k)
        actual_class.append(str(j.split('_')[0]))
    data = pd.DataFrame({'labeled_class':labeled_class,'review':reviews,'actual_class':actual_class})
    return data

# %%
negative_df = preprocess(negative_list,'negative_reviews','negative')
positive_df = preprocess(positive_list,'positive_reviews','positive')

# %%
negative_df.head()
# Out:
#   labeled_class                                             review  \
# 0      negative  My wife and I just spent a long weekend at the...
# 1      negative  The historic feel of the hotel really had a st...
# 2      negative  I haven't actually stayed at this hotel- yet- ...
# 3      negative  I was very much looking forward to our stay at...
# 4      negative  The hotel is almost always very helpful. This ...
#
#   actual_class
# 0            t
# 1            t
# 2            t
# 3            t
# 4            t

# %%
positive_df.head()
# Out:
#   labeled_class                                             review  \
# 0      positive  The Hard Rock Hotel Chicago has become my favo...
# 1      positive  My wife and I had to stay downtown for event t...
# 2      positive  took a weekend trip with my wife. got a great ...
# 3      positive  We stayed here because of all the great review...
# 4      positive  Just returned from a week in Chicago with the ...
#
#   actual_class
# 0            t
# 1            t
# 2            t
# 3            t
# 4            t

# %%
target = []
for i in positive_df.index:
    if ((positive_df['labeled_class'][i] == 'positive') & (positive_df['actual_class'][i] == 't')):
        target.append(2)
    elif ((positive_df['labeled_class'][i] == 'positive') & (positive_df['actual_class'][i] == 'd')):
        target.append(1)
    else:
        print('Error!')
positive_df['target'] = target

# %%
target = []
for i in negative_df.index:
    if ((negative_df['labeled_class'][i] == 'negative') & (negative_df['actual_class'][i] == 't')):
        target.append(3)
    elif ((negative_df['labeled_class'][i] == 'negative') & (negative_df['actual_class'][i] == 'd')):
        target.append(4)
    else:
        print('Error!')
negative_df['target'] = target

# %%
data = positive_df.merge(negative_df,how='outer')

# %%
data = data[['review','target']]

# %%
data.head()
# Out:
#                                               review  target
# 0  The Hard Rock Hotel Chicago has become my favo...       2
# 1  My wife and I had to stay downtown for event t...       2
# 2  took a weekend trip with my wife. got a great ...       2
# 3  We stayed here because of all the great review...       2
# 4  Just returned from a week in Chicago with the ...       2

# %%
data.target.value_counts()
# Out:
# 4    410
# 3    400
# 2    400
# 1    400
# Name: target, dtype: int64

# %%
#Using Spacy to get tokens and pos tags

# %%
nlp=spacy.load('en',entity='false');

# %%
#pos_tags=[];
#g=[[]];
#for datapoint in data['review_tokenized']:
 #   s=""
  #  for j in datapoint:
   #     s=s+str(j)+"_"+j.pos_;
    #    s=s+","
    #t=s;    
    #pos_tags.append(t)  
    #g.append(pos_tags)
#print(g)

# %%
tokens = []
lemma = []
pos = []
for doc in nlp.pipe(data['review'].astype('unicode').values, batch_size=50,
                        n_threads=6):
    if doc.is_parsed:
        tokens.append(str([n.text for n in doc ]))
        lemma.append([n.lemma_ for n in doc])
        pos.append([n.pos_ for n in doc])
    else:
        # We want to make sure that the lists of parsed results have the
        # same number of entries of the original Dataframe, so add some blanks in case the parse fails
        tokens.append(None)
        lemma.append(None)
        pos.append(None)   
        
data['species_tokens'] = tokens
data['species_lemma'] = lemma
data['species_pos'] = pos

# %%
data['species_tokens']
# Out:
# 0       ['The', 'Hard', 'Rock', 'Hotel', 'Chicago', 'h...
# 1       ['My', 'wife', 'and', 'I', 'had', 'to', 'stay'...
# 2       ['took', 'a', 'weekend', 'trip', 'with', 'my',...
# 3       ['We', 'stayed', 'here', 'because', 'of', 'all...
# 4       ['Just', 'returned', 'from', 'a', 'week', 'in'...
# 5       ['We', 'stayed', 'at', 'the', 'Swissotel', 'fo...
# 6       ['I', 'just', 'left', 'the', 'Conrad', 'Chicag...
# 7       ['This', 'is', 'a', 'great', 'hotel', '!', 'Th...
# 8       ['Got', 'a', 'good', 'deal', 'on', 'a', 'weeke...
# 9       ['Thirty', 'years', 'ago', ',', 'we', 'had', '...
# 10      ['I', 'stayed', 'here', 'August', '20', 'throu...
# 11      ['The', 'Omni', 'Chicago', 'Hotel', 'I', 'am',...
# 12      ['excellent', 'staff', 'and', 'customer', 'ser...
# 13      ['I', 'am', 'a', 'fan', 'of', 'Kimpton', 'Hote...
# 14      ['I', 'stay', 'at', 'this', 'hotel', '2', 'tim...
# 15      ['The', 'InterContinental', 'Chicago', 'is', '...
# 16      ['This', 'hotel', 'was', 'wonderful', '!', 'I'...
# 17      ['I', 'love', 'the', 'Ambassador', 'East', ','...
# 18      ['Beautiful', 'views', 'and', 'awesome', 'serv...
# 19      ['The', 'entrance', 'and', 'room', 'was', 'spa...
# 20      ['We', 'absolutely', 'loved', 'the', 'Knickerb...
# 21      ['I', 'traveled', 'to', 'Chicago', 'with', 'my...
# 22      ['We', 'booked', 'our', 'room', 'on', 'Priceli...
# 23      ['Just', 'returned', 'from', 'a', '3', 'night'...
# 24      ['I', 'stayed', 'at', 'The', 'Talbott', 'for',...
# 25      ['I', 'booked', 'a', 'room', 'at', 'the', 'Hya...
# 26      ['I', 'stayed', 'in', 'the', 'Sofitel', 'Chica...
# 27      ['My', 'first', 'trip', 'back', 'to', 'Chicago...
# 28      ['My', 'family', 'really', 'enjoyed', 'this', ...
# 29      ['The', 'Swissotel', 'Chicago', 'is', 'a', 'de...
#                               ...
# 1580    ['Here', 'are', 'some', 'pros', 'and', 'cons',...
# 1581    ['My', 'stay', 'at', 'the', 'Homewood', 'Suite...
# 1582    ['I', 'would', 'not', 'stay', 'at', 'this', 'h...
# 1583    ['Me', 'and', 'my', 'wife', 'stayed', 'at', 't...
# 1584    ['My', 'husband', 'and', 'I', 'were', 'plannin...
# 1585    ['Whilst', 'no', 'doubt', 'being', 'in', 'a', ...
# 1586    ['We', 'did', "n't", 'stay', 'in', 'the', 'hot...
# 1587    ['I', 'am', 'staying', 'here', 'now', 'and', '...
# 1588    ['The', 'Swissotel', 'Chicago', 'is', 'a', 've...
# 1589    ['This', 'was', 'the', '2nd', 'time', 'that', ...
# 1590    ['Just', 'back', 'from', 'spending', 'Memorial...
# 1591    ['Ok', ',', 'I', 'just', 'feel', 'if', 'you', ...
# 1592    ['Outmoded', 'and', 'worn', 'furnishings', 'co...
# 1593    ['I', 'am', 'writing', 'in', 'regards', 'to', ...
# 1594    ['I', 'ca', "n't", 'recall', 'another', 'time'...
# 1595    ['The', 'hotel', 'lost', 'our', 'reservations'...
# 1596    ['Used', 'this', 'hotel', 'the', 'first', 'tim...
# 1597    ['Seriously', 'overpriced', 'The', 'room', 'wa...
# 1598    ['I', 'had', 'really', 'high', 'hopes', 'for',...
# 1599    ['We', 'enjoyed', 'the', 'Hotel', 'Monaco', '....
# 1600    ['The', 'hotel', 'was', 'undergoing', 'renovat...
# 1601    ['My', 'son', '&', 'I', 'joined', 'my', 'husba...
# 1602    ['My', 'wife', 'and', 'I', 'went', 'to', 'Chic...
# 1603    ['After', 'a', 'recent', 'stay', 'at', 'the', ...
# 1604    ['The', 'Omni', 'Chicago', 'Hotel', 'is', 'not...
# 1605    ['I', 'had', 'an', 'awful', 'experience', 'her...
# 1606    ['We', 'experienced', 'bed', 'bugs', 'in', 'ou...
# 1607    ['I', 'recently', 'stayed', 'at', 'the', 'Affi...
# 1608    ['The', 'room', 'was', 'big', 'and', 'luxuriou...
# 1609    ['My', 'two', 'girlfriends', 'and', 'I', 'arri...
# Name: species_tokens, Length: 1610, dtype: object

# %%
#data['species_pos'] = data['species_pos'].astype(str).apply(lambda x: ', '.join(data['species_pos'].astype(str)))

# %%
data
# Out:
#                                                  review  target  \
# 0     The Hard Rock Hotel Chicago has become my favo...       2
# 1     My wife and I had to stay downtown for event t...       2
# 2     took a weekend trip with my wife. got a great ...       2
# 3     We stayed here because of all the great review...       2
# 4     Just returned from a week in Chicago with the ...       2
# 5     We stayed at the Swissotel for a special birth...       2
# 6     I just left the Conrad Chicago and have nothin...       2
# 7     This is a great hotel! The views are fabulous,...       2
# 8     Got a good deal on a weekend pacage in this Ho...       2
# 9     Thirty years ago, we had a tiny "room" and ind...       2
# 10    I stayed here August 20 through 23rd with my s...       2
# 11    The Omni Chicago Hotel I am a business woman w...       1
# 12    excellent staff and customer service, very cle...       1
# 13    I am a fan of Kimpton Hotels, however I have n...       2
# 14    I stay at this hotel 2 times a year on busines...       2
# 15    The InterContinental Chicago is conveniently l...       1
# 16    This hotel was wonderful! I am a college stude...       2
# 17    I love the Ambassador East, true, she's a litt...       2
# 18    Beautiful views and awesome service! My husban...       1
# 19    The entrance and room was spacious and modern,...       1
# 20    We absolutely loved the Knickerbocker. Now, if...       2
# 21    I traveled to Chicago with my husband for a ro...       1
# 22    We booked our room on Priceline, and got a goo...       2
# 23    Just returned from a 3 night stay at the Talbo...       2
# 24    I stayed at The Talbott for 3 nights on busine...       2
# 25    I booked a room at the Hyatt through Priceline...       2
# 26    I stayed in the Sofitel Chicago Water Tower ho...       1
# 27    My first trip back to Chicago in about 7 years...       2
# 28    My family really enjoyed this hotel the weeken...       1
# 29    The Swissotel Chicago is a delight to visit. L...       1
# ...                                                 ...     ...
# 1580  Here are some pros and cons: Pros: -Good locat...       3
# 1581  My stay at the Homewood Suites in downtown Chi...       4
# 1582  I would not stay at this hotel again. The room...       4
# 1583  Me and my wife stayed at the Omni hotel in Chi...       4
# 1584  My husband and I were planning our 1st year we...       4
# 1585  Whilst no doubt being in a good location this ...       4
# 1586  We didn't stay in the hotel a lot because we w...       3
# 1587  I am staying here now and actually am compelle...       3
# 1588  The Swissotel Chicago is a very mediocre hotel...       4
# 1589  This was the 2nd time that we have stayed at t...       3
# 1590  Just back from spending Memorial Day weekend i...       3
# 1591  Ok, I just feel if you're paying well over $20...       3
# 1592  Outmoded and worn furnishings combine with som...       3
# 1593  I am writing in regards to our stay April 22-2...       3
# 1594  I can't recall another time I've had to deal w...       3
# 1595  The hotel lost our reservations and then could...       3
# 1596  Used this hotel the first time I was in Chicag...       3
# 1597  Seriously overpriced The room was clean and co...       3
# 1598  I had really high hopes for this hotel. The lo...       4
# 1599  We enjoyed the Hotel Monaco. Great location fo...       3
# 1600  The hotel was undergoing renovations so it was...       3
# 1601  My son & I joined my husband on a work trip. W...       3
# 1602  My wife and I went to Chicago to enjoy our wee...       4
# 1603  After a recent stay at the Talbott Hotel in Ch...       4
# 1604  The Omni Chicago Hotel is not pretty as they a...       4
# 1605  I had an awful experience here. The staff were...       4
# 1606  We experienced bed bugs in our room while stay...       3
# 1607  I recently stayed at the Affina Chicago hotel ...       4
# 1608  The room was big and luxurious, befitting the ...       3
# 1609  My two girlfriends and I arrived at the hotel,...       3
#
#                                          species_tokens  \
# 0     ['The', 'Hard', 'Rock', 'Hotel', 'Chicago', 'h...
# 1     ['My', 'wife', 'and', 'I', 'had', 'to', 'stay'...
# 2     ['took', 'a', 'weekend', 'trip', 'with', 'my',...
# 3     ['We', 'stayed', 'here', 'because', 'of', 'all...
# 4     ['Just', 'returned', 'from', 'a', 'week', 'in'...
# 5     ['We', 'stayed', 'at', 'the', 'Swissotel', 'fo...
# 6     ['I', 'just', 'left', 'the', 'Conrad', 'Chicag...
# 7     ['This', 'is', 'a', 'great', 'hotel', '!', 'Th...
# 8     ['Got', 'a', 'good', 'deal', 'on', 'a', 'weeke...
# 9     ['Thirty', 'years', 'ago', ',', 'we', 'had', '...
# 10    ['I', 'stayed', 'here', 'August', '20', 'throu...
# 11    ['The', 'Omni', 'Chicago', 'Hotel', 'I', 'am',...
# 12    ['excellent', 'staff', 'and', 'customer', 'ser...
# 13    ['I', 'am', 'a', 'fan', 'of', 'Kimpton', 'Hote...
# 14    ['I', 'stay', 'at', 'this', 'hotel', '2', 'tim...
# 15    ['The', 'InterContinental', 'Chicago', 'is', '...
# 16    ['This', 'hotel', 'was', 'wonderful', '!', 'I'...
# 17    ['I', 'love', 'the', 'Ambassador', 'East', ','...
# 18    ['Beautiful', 'views', 'and', 'awesome', 'serv...
# 19    ['The', 'entrance', 'and', 'room', 'was', 'spa...
# 20    ['We', 'absolutely', 'loved', 'the', 'Knickerb...
# 21    ['I', 'traveled', 'to', 'Chicago', 'with', 'my...
# 22    ['We', 'booked', 'our', 'room', 'on', 'Priceli...
# 23    ['Just', 'returned', 'from', 'a', '3', 'night'...
# 24    ['I', 'stayed', 'at', 'The', 'Talbott', 'for',...
# 25    ['I', 'booked', 'a', 'room', 'at', 'the', 'Hya...
# 26    ['I', 'stayed', 'in', 'the', 'Sofitel', 'Chica...
# 27    ['My', 'first', 'trip', 'back', 'to', 'Chicago...
# 28    ['My', 'family', 'really', 'enjoyed', 'this', ...
# 29    ['The', 'Swissotel', 'Chicago', 'is', 'a', 'de...
# ...                                                 ...
# 1580  ['Here', 'are', 'some', 'pros', 'and', 'cons',...
# 1581  ['My', 'stay', 'at', 'the', 'Homewood', 'Suite...
# 1582  ['I', 'would', 'not', 'stay', 'at', 'this', 'h...
# 1583  ['Me', 'and', 'my', 'wife', 'stayed', 'at', 't...
# 1584  ['My', 'husband', 'and', 'I', 'were', 'plannin...
# 1585  ['Whilst', 'no', 'doubt', 'being', 'in', 'a', ...
# 1586  ['We', 'did', "n't", 'stay', 'in', 'the', 'hot...
# 1587  ['I', 'am', 'staying', 'here', 'now', 'and', '...
# 1588  ['The', 'Swissotel', 'Chicago', 'is', 'a', 've...
# 1589  ['This', 'was', 'the', '2nd', 'time', 'that', ...
# 1590  ['Just', 'back', 'from', 'spending', 'Memorial...
# 1591  ['Ok', ',', 'I', 'just', 'feel', 'if', 'you', ...
# 1592  ['Outmoded', 'and', 'worn', 'furnishings', 'co...
# 1593  ['I', 'am', 'writing', 'in', 'regards', 'to', ...
# 1594  ['I', 'ca', "n't", 'recall', 'another', 'time'...
# 1595  ['The', 'hotel', 'lost', 'our', 'reservations'...
# 1596  ['Used', 'this', 'hotel', 'the', 'first', 'tim...
# 1597  ['Seriously', 'overpriced', 'The', 'room', 'wa...
# 1598  ['I', 'had', 'really', 'high', 'hopes', 'for',...
# 1599  ['We', 'enjoyed', 'the', 'Hotel', 'Monaco', '....
# 1600  ['The', 'hotel', 'was', 'undergoing', 'renovat...
# 1601  ['My', 'son', '&', 'I', 'joined', 'my', 'husba...
# 1602  ['My', 'wife', 'and', 'I', 'went', 'to', 'Chic...
# 1603  ['After', 'a', 'recent', 'stay', 'at', 'the', ...
# 1604  ['The', 'Omni', 'Chicago', 'Hotel', 'is', 'not...
# 1605  ['I', 'had', 'an', 'awful', 'experience', 'her...
# 1606  ['We', 'experienced', 'bed', 'bugs', 'in', 'ou...
# 1607  ['I', 'recently', 'stayed', 'at', 'the', 'Affi...
# 1608  ['The', 'room', 'was', 'big', 'and', 'luxuriou...
# 1609  ['My', 'two', 'girlfriends', 'and', 'I', 'arri...
#
#                                           species_lemma  \
# 0     [the, hard, rock, hotel, chicago, have, become...
# 1     [-PRON-, wife, and, -PRON-, have, to, stay, do...
# 2     [take, a, weekend, trip, with, -PRON-, wife, ....
# 3     [-PRON-, stay, here, because, of, all, the, gr...
# 4     [just, return, from, a, week, in, chicago, wit...
# 5     [-PRON-, stay, at, the, swissotel, for, a, spe...
# 6     [-PRON-, just, leave, the, conrad, chicago, an...
# 7     [this, be, a, great, hotel, !, the, view, be, ...
# 8     [get, a, good, deal, on, a, weekend, pacage, i...
# 9     [thirty, year, ago, ,, -PRON-, have, a, tiny, ...
# 10    [-PRON-, stay, here, august, 20, through, 23rd...
# 11    [the, omni, chicago, hotel, -PRON-, be, a, bus...
# 12    [excellent, staff, and, customer, service, ,, ...
# 13    [-PRON-, be, a, fan, of, kimpton, hotels, ,, h...
# 14    [-PRON-, stay, at, this, hotel, 2, time, a, ye...
# 15    [the, intercontinental, chicago, be, convenien...
# 16    [this, hotel, be, wonderful, !, -PRON-, be, a,...
# 17    [-PRON-, love, the, ambassador, east, ,, true,...
# 18    [beautiful, view, and, awesome, service, !, -P...
# 19    [the, entrance, and, room, be, spacious, and, ...
# 20    [-PRON-, absolutely, love, the, knickerbocker,...
# 21    [-PRON-, travel, to, chicago, with, -PRON-, hu...
# 22    [-PRON-, book, -PRON-, room, on, priceline, ,,...
# 23    [just, return, from, a, 3, night, stay, at, th...
# 24    [-PRON-, stay, at, the, talbott, for, 3, night...
# 25    [-PRON-, book, a, room, at, the, hyatt, throug...
# 26    [-PRON-, stay, in, the, sofitel, chicago, wate...
# 27    [-PRON-, first, trip, back, to, chicago, in, a...
# 28    [-PRON-, family, really, enjoy, this, hotel, t...
# 29    [the, swissotel, chicago, be, a, delight, to, ...
# ...                                                 ...
# 1580  [here, be, some, pro, and, con, :, pro, :, -go...
# 1581  [-PRON-, stay, at, the, homewood, suites, in, ...
# 1582  [-PRON-, would, not, stay, at, this, hotel, ag...
# 1583  [-PRON-, and, -PRON-, wife, stay, at, the, omn...
# 1584  [-PRON-, husband, and, -PRON-, be, plan, -PRON...
# 1585  [whilst, no, doubt, be, in, a, good, location,...
# 1586  [-PRON-, do, not, stay, in, the, hotel, a, lot...
# 1587  [-PRON-, be, stay, here, now, and, actually, b...
# 1588  [the, swissotel, chicago, be, a, very, mediocr...
# 1589  [this, be, the, 2nd, time, that, -PRON-, have,...
# 1590  [just, back, from, spend, memorial, day, weeke...
# 1591  [ok, ,, -PRON-, just, feel, if, -PRON-, be, pa...
# 1592  [outmoded, and, worn, furnishing, combine, wit...
# 1593  [-PRON-, be, write, in, regard, to, -PRON-, st...
# 1594  [-PRON-, can, not, recall, another, time, -PRO...
# 1595  [the, hotel, lose, -PRON-, reservation, and, t...
# 1596  [use, this, hotel, the, first, time, -PRON-, b...
# 1597  [seriously, overprice, the, room, be, clean, a...
# 1598  [-PRON-, have, really, high, hope, for, this, ...
# 1599  [-PRON-, enjoy, the, hotel, monaco, ., great, ...
# 1600  [the, hotel, be, undergo, renovation, so, -PRO...
# 1601  [-PRON-, son, &, -PRON-, join, -PRON-, husband...
# 1602  [-PRON-, wife, and, -PRON-, go, to, chicago, t...
# 1603  [after, a, recent, stay, at, the, talbott, hot...
# 1604  [the, omni, chicago, hotel, be, not, pretty, a...
# 1605  [-PRON-, have, an, awful, experience, here, .,...
# 1606  [-PRON-, experience, bed, bug, in, -PRON-, roo...
# 1607  [-PRON-, recently, stay, at, the, affina, chic...
# 1608  [the, room, be, big, and, luxurious, ,, befit,...
# 1609  [-PRON-, two, girlfriend, and, -PRON-, arrive,...
#
#                                             species_pos
# 0     [DET, PROPN, PROPN, PROPN, PROPN, VERB, VERB, ...
# 1     [ADJ, NOUN, CCONJ, PRON, VERB, PART, VERB, NOU...
# 2     [VERB, DET, NOUN, NOUN, ADP, ADJ, NOUN, PUNCT,...
# 3     [PRON, VERB, ADV, ADP, ADP, ADJ, DET, ADJ, NOU...
# 4     [ADV, VERB, ADP, DET, NOUN, ADP, PROPN, ADP, D...
# 5     [PRON, VERB, ADP, DET, PROPN, ADP, DET, ADJ, N...
# 6     [PRON, ADV, VERB, DET, PROPN, PROPN, CCONJ, VE...
# 7     [DET, VERB, DET, ADJ, NOUN, PUNCT, DET, NOUN, ...
# 8     [VERB, DET, ADJ, NOUN, ADP, DET, NOUN, NOUN, A...
# 9     [NUM, NOUN, ADV, PUNCT, PRON, VERB, DET, ADJ, ...
# 10    [PRON, VERB, ADV, PROPN, NUM, ADP, NOUN, ADP, ...
# 11    [DET, PROPN, PROPN, PROPN, PRON, VERB, DET, NO...
# 12    [ADJ, NOUN, CCONJ, NOUN, NOUN, PUNCT, ADV, ADJ...
# 13    [PRON, VERB, DET, NOUN, ADP, PROPN, PROPN, PUN...
# 14    [PRON, VERB, ADP, DET, NOUN, NUM, NOUN, DET, N...
# 15    [DET, PROPN, PROPN, VERB, ADV, VERB, ADP, PROP...
# 16    [DET, NOUN, VERB, ADJ, PUNCT, PRON, VERB, DET,...
# 17    [PRON, VERB, DET, PROPN, PROPN, PUNCT, ADJ, PU...
# 18    [ADJ, NOUN, CCONJ, ADJ, NOUN, PUNCT, ADJ, NOUN...
# 19    [DET, NOUN, CCONJ, NOUN, VERB, ADJ, CCONJ, ADJ...
# 20    [PRON, ADV, VERB, DET, PROPN, PUNCT, ADV, PUNC...
# 21    [PRON, VERB, ADP, PROPN, ADP, ADJ, NOUN, ADP, ...
# 22    [PRON, VERB, ADJ, NOUN, ADP, PROPN, PUNCT, CCO...
# 23    [ADV, VERB, ADP, DET, NUM, NOUN, NOUN, ADP, DE...
# 24    [PRON, VERB, ADP, DET, PROPN, ADP, NUM, NOUN, ...
# 25    [PRON, VERB, DET, NOUN, ADP, DET, PROPN, ADP, ...
# 26    [PRON, VERB, ADP, DET, PROPN, PROPN, PROPN, PR...
# 27    [ADJ, ADJ, NOUN, ADV, ADP, PROPN, ADP, ADV, NU...
# 28    [ADJ, NOUN, ADV, VERB, DET, NOUN, DET, NOUN, P...
# 29    [DET, PROPN, PROPN, VERB, DET, NOUN, PART, VER...
# ...                                                 ...
# 1580  [ADV, VERB, DET, NOUN, CCONJ, NOUN, PUNCT, NOU...
# 1581  [ADJ, NOUN, ADP, DET, PROPN, PROPN, ADP, NOUN,...
# 1582  [PRON, VERB, ADV, VERB, ADP, DET, NOUN, ADV, P...
# 1583  [PRON, CCONJ, ADJ, NOUN, VERB, ADP, DET, PROPN...
# 1584  [ADJ, NOUN, CCONJ, PRON, VERB, VERB, ADJ, ADJ,...
# 1585  [ADP, ADV, ADV, VERB, ADP, DET, ADJ, NOUN, DET...
# 1586  [PRON, VERB, ADV, VERB, ADP, DET, NOUN, DET, N...
# 1587  [PRON, VERB, VERB, ADV, ADV, CCONJ, ADV, VERB,...
# 1588  [DET, PROPN, PROPN, VERB, DET, ADV, ADJ, NOUN,...
# 1589  [DET, VERB, DET, ADJ, NOUN, ADJ, PRON, VERB, V...
# 1590  [ADV, ADV, ADP, VERB, PROPN, PROPN, NOUN, ADP,...
# 1591  [INTJ, PUNCT, PRON, ADV, VERB, ADP, PRON, VERB...
# 1592  [ADJ, CCONJ, ADJ, NOUN, VERB, ADP, DET, ADJ, A...
# 1593  [PRON, VERB, VERB, ADP, NOUN, ADP, ADJ, ADJ, P...
# 1594  [PRON, VERB, ADV, VERB, DET, NOUN, PRON, VERB,...
# 1595  [DET, NOUN, VERB, ADJ, NOUN, CCONJ, ADV, ADJ, ...
# 1596  [VERB, DET, NOUN, DET, ADJ, NOUN, PRON, VERB, ...
# 1597  [ADV, VERB, DET, NOUN, VERB, ADJ, CCONJ, ADJ, ...
# 1598  [PRON, VERB, ADV, ADJ, NOUN, ADP, DET, NOUN, P...
# 1599  [PRON, VERB, DET, PROPN, PROPN, PUNCT, ADJ, NO...
# 1600  [DET, NOUN, VERB, VERB, NOUN, ADP, PRON, VERB,...
# 1601  [ADJ, NOUN, CCONJ, PRON, VERB, ADJ, NOUN, ADP,...
# 1602  [ADJ, NOUN, CCONJ, PRON, VERB, ADP, PROPN, PAR...
# 1603  [ADP, DET, ADJ, NOUN, ADP, DET, PROPN, PROPN, ...
# 1604  [DET, PROPN, PROPN, PROPN, VERB, ADV, ADJ, ADP...
# 1605  [PRON, VERB, DET, ADJ, NOUN, ADV, PUNCT, DET, ...
# 1606  [PRON, VERB, NOUN, NOUN, ADP, ADJ, NOUN, ADP, ...
# 1607  [PRON, ADV, VERB, ADP, DET, PROPN, PROPN, NOUN...
# 1608  [DET, NOUN, VERB, ADJ, CCONJ, ADJ, PUNCT, VERB...
# 1609  [ADJ, NUM, NOUN, CCONJ, PRON, VERB, ADP, DET, ...
#
# [1610 rows x 5 columns]

# %%
col = []
for i,j in zip(data['species_tokens'], data['species_pos']):
   col.append([ x+'_'+ y for x,y in zip(eval(i),j)])

# %%
col[:10]
# Out:
# [['The_DET',
#   'Hard_PROPN',
#   'Rock_PROPN',
#   'Hotel_PROPN',
#   'Chicago_PROPN',
#   'has_VERB',
#   'become_VERB',
#   'my_ADJ',
#   'favorite_ADJ',
#   'hotel_NOUN',
#   '._PUNCT',
#   'I_PRON',
#   "'ve_VERB",
#   'stayed_VERB',
#   'there_ADV',
#   'at_ADV',
#   'least_ADV',
#   '5_NUM',
#   'times_NOUN',
#   'now_ADV',
#   'and_CCONJ',
#   'have_VERB',
#   'never_ADV',
#   'had_VERB',
#   'anything_NOUN',
#   'other_ADJ',
#   'than_ADP',
#   'a_DET',
#   'wonderful_ADJ',
#   'experience_NOUN',
#   '._PUNCT',
#   'As_ADP',
#   'you_PRON',
#   'might_VERB',
#   'have_VERB',
#   'guessed_VERB',
#   '-_PUNCT',
#   'it_PRON',
#   'has_VERB',
#   'a_DET',
#   'super_ADJ',
#   'Rock_PROPN',
#   '&_CCONJ',
#   'Roll_PROPN',
#   'theme_NOUN',
#   ',_PUNCT',
#   'with_ADP',
#   'some_DET',
#   'music_NOUN',
#   'paraphanelia_NOUN',
#   'in_ADP',
#   'the_DET',
#   'lobby_NOUN',
#   'and_CCONJ',
#   'on_ADP',
#   'each_DET',
#   'floor_NOUN',
#   "'s_PART",
#   'elevator_NOUN',
#   'lobby_NOUN',
#   '._PUNCT',
#   'The_DET',
#   'rooms_NOUN',
#   'all_DET',
#   'have_VERB',
#   'large_ADJ',
#   'photo_NOUN',
#   'murals_NOUN',
#   'that_ADJ',
#   'are_VERB',
#   'themed_VERB',
#   'to_ADP',
#   'different_ADJ',
#   'musicians_NOUN',
#   '._PUNCT',
#   'You_PRON',
#   'can_VERB',
#   'request_VERB',
#   'being_VERB',
#   'on_ADP',
#   'the_DET',
#   'floor_NOUN',
#   'of_ADP',
#   'your_ADJ',
#   'favorite_ADJ',
#   'band_NOUN',
#   '(_PUNCT',
#   'like_ADP',
#   'KISS_PROPN',
#   ',_PUNCT',
#   'Aerosmith_PROPN',
#   ',_PUNCT',
#   'etc_X',
#   '..._PUNCT',
#   ')_PUNCT',
#   'The_DET',
#   'rooms_NOUN',
#   'are_VERB',
#   'GREAT_ADJ',
#   '._PUNCT',
#   'Well_INTJ',
#   'appointed_VERB',
#   '._PUNCT',
#   'SUPER_PROPN',
#   'Comfortable_PROPN',
#   'beds_NOUN',
#   'and_CCONJ',
#   'luxurious_ADJ',
#   'sheets_NOUN',
#   'and_CCONJ',
#   'wonderous_ADJ',
#   'pillows_NOUN',
#   '._PUNCT',
#   'The_DET',
#   'large_ADJ',
#   'TV_NOUN',
#   'has_VERB',
#   'a_DET',
#   'cool_ADJ',
#   'sound_NOUN',
#   'system_NOUN',
#   'that_ADJ',
#   'ramps_VERB',
#   'up_PART',
#   'the_DET',
#   'viewing_VERB',
#   'experience_NOUN',
#   '._PUNCT',
#   'There_ADV',
#   "'s_VERB",
#   'a_DET',
#   'spacious_ADJ',
#   'desk_NOUN',
#   'in_ADP',
#   'each_DET',
#   'room_NOUN',
#   'with_ADP',
#   'a_DET',
#   'mini_ADJ',
#   'bar_NOUN',
#   '._PUNCT',
#   'I_PRON',
#   "'ve_VERB",
#   'always_ADV',
#   'had_VERB',
#   'a_DET',
#   'room_NOUN',
#   'with_ADP',
#   'big_ADJ',
#   'windows_NOUN',
#   'and_CCONJ',
#   'a_DET',
#   'view_NOUN',
#   'down_ADP',
#   'Michigan_PROPN',
#   'Ave_PROPN',
#   '(_PUNCT',
#   'the_DET',
#   'hotel_NOUN',
#   'sits_VERB',
#   'right_ADV',
#   'on_ADP',
#   'Michigan_PROPN',
#   '-_PUNCT',
#   'a_DET',
#   'block_NOUN',
#   'from_ADP',
#   'the_DET',
#   'canal_NOUN',
#   ')_PUNCT',
#   '._PUNCT',
#   'The_DET',
#   'bathrooms_NOUN',
#   'are_VERB',
#   'furnished_VERB',
#   'with_ADP',
#   'absolutely_ADV',
#   'great_ADJ',
#   'fixtures_NOUN',
#   'sporting_VERB',
#   'a_DET',
#   'great_ADJ',
#   'design_NOUN',
#   '..._PUNCT',
#   'some_DET',
#   'of_ADP',
#   'the_DET',
#   'showers_NOUN',
#   'have_VERB',
#   'windows_NOUN',
#   'in_ADP',
#   'side_NOUN',
#   'of_ADP',
#   'them_PRON',
#   '(_PUNCT',
#   'you_PRON',
#   'can_VERB',
#   'shower_VERB',
#   'AND_CCONJ',
#   'enjoy_VERB',
#   'the_DET',
#   'view_NOUN',
#   'down_ADP',
#   'Michigan_PROPN',
#   '!_PUNCT',
#   ')_PUNCT',
#   'or_CCONJ',
#   'close_VERB',
#   'the_DET',
#   'waterproof_ADJ',
#   'drapes_NOUN',
#   '._PUNCT',
#   'I_PRON',
#   "'ve_VERB",
#   'never_ADV',
#   'had_VERB',
#   'anything_NOUN',
#   'but_ADP',
#   'a_DET',
#   'great_ADJ',
#   'experience_NOUN',
#   'with_ADP',
#   'the_DET',
#   'staff_NOUN',
#   'here_ADV',
#   '..._PUNCT',
#   'front_ADJ',
#   'desk_NOUN',
#   ',_PUNCT',
#   'doorman_NOUN',
#   ',_PUNCT',
#   'etc_X',
#   'are_VERB',
#   'all_ADV',
#   'great_ADJ',
#   '._PUNCT',
#   'There_ADV',
#   "'s_VERB",
#   'a_DET',
#   'lobby_NOUN',
#   'bar_NOUN',
#   'that_ADJ',
#   'still_ADV',
#   'feels_VERB',
#   'intimate_ADJ',
#   'and_CCONJ',
#   'has_VERB',
#   'nice_ADJ',
#   'energy_NOUN',
#   '._PUNCT',
#   'Big_ADJ',
#   'screen_NOUN',
#   'TV_NOUN',
#   'to_PART',
#   'catch_VERB',
#   'the_DET',
#   'latest_ADJ',
#   'scores_NOUN',
#   ',_PUNCT',
#   'too_ADV',
#   '._PUNCT',
#   'Of_ADV',
#   'course_ADV',
#   ',_PUNCT',
#   'Rock_PROPN',
#   '&_CCONJ',
#   'Roll_PROPN',
#   'music_NOUN',
#   'pumps_VERB',
#   'thru_ADP',
#   'the_DET',
#   'place_NOUN',
#   '._PUNCT',
#   'You_PRON',
#   'can_VERB',
#   'stay_VERB',
#   'at_ADP',
#   'a_DET',
#   '"_PUNCT',
#   'plain_ADJ',
#   '"_PUNCT',
#   'hotel_NOUN',
#   'anywhere_ADV',
#   '..._PUNCT',
#   'but_CCONJ',
#   'this_DET',
#   'is_VERB',
#   'a_DET',
#   'GREAT_ADJ',
#   ',_PUNCT',
#   'WELL_INTJ',
#   'DESIGNED_PROPN',
#   ',_PUNCT',
#   'FUN_PROPN',
#   'and_CCONJ',
#   'MEMORABLE_PROPN',
#   'HOTEL_PROPN',
#   'that_ADJ',
#   'you_PRON',
#   "'ll_VERB",
#   'want_VERB',
#   'to_PART',
#   'return_VERB',
#   'back_ADV',
#   'to_ADP',
#   '._PUNCT',
#   'If_ADP',
#   'I_PRON',
#   'had_VERB',
#   'one_NUM',
#   'concern_NOUN',
#   '-_PUNCT',
#   'it_PRON',
#   'would_VERB',
#   'be_VERB',
#   'the_DET',
#   'rather_ADV',
#   'crazy_ADJ',
#   'charge_NOUN',
#   'for_ADP',
#   'parking_NOUN',
#   'your_ADJ',
#   'car_NOUN',
#   'overnight_ADV',
#   '._PUNCT',
#   'My_ADJ',
#   'daily_ADJ',
#   'car_NOUN',
#   'parking_NOUN',
#   'rate_NOUN',
#   'was_VERB',
#   'close_ADJ',
#   'to_ADP',
#   '$_SYM',
#   '50_NUM',
#   'per_ADP',
#   'night_NOUN',
#   ',_PUNCT',
#   'which_ADJ',
#   'I_PRON',
#   "'m_VERB",
#   'sorry_ADJ',
#   'to_PART',
#   'say_VERB',
#   'is_VERB',
#   'about_ADP',
#   'the_DET',
#   'going_VERB',
#   'rate_NOUN',
#   'in_ADP',
#   'the_DET',
#   'loop_NOUN',
#   '._PUNCT',
#   'Stay_VERB',
#   'here_ADV',
#   '._PUNCT',
#   'Be_VERB',
#   'cool_ADJ',
#   '._PUNCT',
#   '\n_SPACE'],
#  ['My_ADJ',
#   'wife_NOUN',
#   'and_CCONJ',
#   'I_PRON',
#   'had_VERB',
#   'to_PART',
#   'stay_VERB',
#   'downtown_NOUN',
#   'for_ADP',
#   'event_NOUN',
#   'that_ADP',
#   'we_PRON',
#   'were_VERB',
#   'attending_VERB',
#   'at_ADP',
#   'the_DET',
#   'Drake_PROPN',
#   'Hotel_PROPN',
#   '._PUNCT',
#   'I_PRON',
#   'have_VERB',
#   'stayed_VERB',
#   'at_ADP',
#   'the_DET',
#   'Drake_PROPN',
#   'before_ADV',
#   'and_CCONJ',
#   'while_ADP',
#   'it_PRON',
#   'is_VERB',
#   'nice_ADJ',
#   ',_PUNCT',
#   'it_PRON',
#   'is_VERB',
#   'bit_NOUN',
#   'stuffy_ADJ',
#   'and_CCONJ',
#   'a_DET',
#   'little_ADJ',
#   'outdated_ADJ',
#   'for_ADP',
#   'the_DET',
#   'price_NOUN',
#   '._PUNCT',
#   'We_PRON',
#   'opted_VERB',
#   'to_PART',
#   'walk_VERB',
#   'across_ADP',
#   'the_DET',
#   'street_NOUN',
#   'and_CCONJ',
#   'stay_VERB',
#   'at_ADP',
#   'the_DET',
#   'Millenium_PROPN',
#   'instead_ADV',
#   '._PUNCT',
#   'I_PRON',
#   'know_VERB',
#   'this_DET',
#   'property_NOUN',
#   'has_VERB',
#   'under_ADP',
#   'gone_VERB',
#   'many_ADJ',
#   'renovations_NOUN',
#   'in_ADP',
#   'past_ADJ',
#   'year_NOUN',
#   'and_CCONJ',
#   'I_PRON',
#   'have_VERB',
#   'to_PART',
#   'say_VERB',
#   'they_PRON',
#   'have_VERB',
#   'done_VERB',
#   'a_DET',
#   'great_ADJ',
#   'job_NOUN',
#   '._PUNCT',
#   'This_DET',
#   'place_NOUN',
#   'used_VERB',
#   'to_PART',
#   'be_VERB',
#   'the_DET',
#   'hotel_NOUN',
#   'you_PRON',
#   'would_VERB',
#   'crash_VERB',
#   'in_ADP',
#   'when_ADV',
#   'you_PRON',
#   'came_VERB',
#   'to_ADP',
#   'Chicago_PROPN',
#   'on_ADP',
#   'a_DET',
#   'college_NOUN',
#   'roadtrip_NOUN',
#   '(_PUNCT',
#   'I_PRON',
#   'did_VERB',
#   ')_PUNCT',
#   '._PUNCT',
#   'But_CCONJ',
#   'that_DET',
#   'is_VERB',
#   'not_ADV',
#   'the_DET',
#   'case_NOUN',
#   'any_DET',
#   'more_ADJ',
#   '._PUNCT',
#   'This_DET',
#   'property_NOUN',
#   'is_VERB',
#   'directly_ADV',
#   'across_ADP',
#   'from_ADP',
#   'the_DET',
#   'Drake_PROPN',
#   'Hotel_PROPN',
#   'and_CCONJ',
#   'for_ADP',
#   '1/2_NUM',
#   'the_DET',
#   'price_NOUN',
#   'you_PRON',
#   'get_VERB',
#   'their_ADJ',
#   'great_ADJ',
#   'location_NOUN',
#   'with_ADP',
#   'a_DET',
#   'newer_ADJ',
#   '(_PUNCT',
#   'albeit_ADP',
#   'smaller_ADJ',
#   ')_PUNCT',
#   'room_NOUN',
#   'and_CCONJ',
#   'every_DET',
#   'ammenity_NOUN',
#   'you_PRON',
#   'would_VERB',
#   'expect_VERB',
#   'from_ADP',
#   'a_DET',
#   '4_NUM',
#   '*_PUNCT',
#   'hotel_NOUN',
#   '._PUNCT',
#   'The_DET',
#   'rooms_NOUN',
#   'are_VERB',
#   'tastefully_ADV',
#   'decorated_VERB',
#   '(_PUNCT',
#   'Asian_ADJ',
#   'influence_NOUN',
#   'w_PROPN',
#   '/_SYM',
#   'flat_ADJ',
#   'screen_NOUN',
#   'tv_NOUN',
#   ')_PUNCT',
#   'and_CCONJ',
#   'the_DET',
#   'bed_NOUN',
#   'is_VERB',
#   'very_ADV',
#   'comfortable_ADJ',
#   '._PUNCT',
#   'The_DET',
#   'bath_NOUN',
#   'is_VERB',
#   'small_ADJ',
#   '(_PUNCT',
#   'no_DET',
#   'tub_NOUN',
#   ')_PUNCT',
#   ',_PUNCT',
#   'but_CCONJ',
#   'very_ADV',
#   'clean_ADJ',
#   'and_CCONJ',
#   'the_DET',
#   'shower_NOUN',
#   'is_VERB',
#   'great_ADJ',
#   '._PUNCT',
#   'You_PRON',
#   'are_VERB',
#   'not_ADV',
#   'going_VERB',
#   'to_PART',
#   'be_VERB',
#   'spending_VERB',
#   'a_DET',
#   'bunch_NOUN',
#   'of_ADP',
#   'time_NOUN',
#   'in_ADP',
#   'your_ADJ',
#   'room_NOUN',
#   'when_ADV',
#   'visting_VERB',
#   'Chicago_PROPN',
#   ',_PUNCT',
#   'so_CCONJ',
#   'the_DET',
#   'room_NOUN',
#   "'s_PART",
#   'size_NOUN',
#   'is_VERB',
#   'not_ADV',
#   'a_DET',
#   'big_ADJ',
#   'deal_NOUN',
#   '._PUNCT',
#   '(_PUNCT',
#   'It_PRON',
#   'works_VERB',
#   'well_ADV',
#   'with_ADP',
#   'a_DET',
#   'couple_NOUN',
#   ',_PUNCT',
#   'but_CCONJ',
#   'a_DET',
#   'family_NOUN',
#   'of_ADP',
#   'four_NUM',
#   'may_VERB',
#   'be_VERB',
#   'a_DET',
#   'bit_NOUN',
#   'cramped_VERB',
#   '._PUNCT',
#   ')_PUNCT',
#   'The_DET',
#   'service_NOUN',
#   'was_VERB',
#   'attentive_ADJ',
#   'and_CCONJ',
#   'friendly_ADJ',
#   'and_CCONJ',
#   'the_DET',
#   'location_NOUN',
#   'ca_VERB',
#   "n't_ADV",
#   'be_VERB',
#   'beat_VERB',
#   '._PUNCT',
#   'I_PRON',
#   'would_VERB',
#   'definitely_ADV',
#   'stay_VERB',
#   'here_ADV',
#   'again_ADV',
#   ',_PUNCT',
#   'but_CCONJ',
#   'the_DET',
#   'next_ADJ',
#   'time_NOUN',
#   'I_PRON',
#   'would_VERB',
#   'leave_VERB',
#   'the_DET',
#   'car_NOUN',
#   'at_ADP',
#   'home_NOUN',
#   '(_PUNCT',
#   '$_SYM',
#   '49/night_NUM',
#   'parking_NOUN',
#   'is_VERB',
#   'a_DET',
#   'bit_NOUN',
#   'steep_ADJ',
#   ')_PUNCT',
#   '._PUNCT',
#   '\n_SPACE'],
#  ['took_VERB',
#   'a_DET',
#   'weekend_NOUN',
#   'trip_NOUN',
#   'with_ADP',
#   'my_ADJ',
#   'wife_NOUN',
#   '._PUNCT',
#   'got_VERB',
#   'a_DET',
#   'great_ADJ',
#   'rate_NOUN',
#   'with_ADP',
#   'valet_NOUN',
#   'included_VERB',
#   ',_PUNCT',
#   'paid_VERB',
#   'a_DET',
#   'couple_NOUN',
#   'extra_ADJ',
#   'bucks_NOUN',
#   'for_ADP',
#   'the_DET',
#   'larger_ADJ',
#   'room_NOUN',
#   '._PUNCT',
#   'staff_NOUN',
#   'was_VERB',
#   'nice_ADJ',
#   ',_PUNCT',
#   'workout_NOUN',
#   'facility_NOUN',
#   'was_VERB',
#   'great_ADJ',
#   '._PUNCT',
#   'room_NOUN',
#   'has_VERB',
#   'current_ADJ',
#   'decor_NOUN',
#   ',_PUNCT',
#   'but_CCONJ',
#   'was_VERB',
#   'starting_VERB',
#   'to_PART',
#   'show_VERB',
#   'some_DET',
#   'wear_NOUN',
#   '._PUNCT',
#   'watch_VERB',
#   'the_DET',
#   'concierge_NOUN',
#   ',_PUNCT',
#   'she_PRON',
#   'suggested_VERB',
#   'a_DET',
#   'pretty_ADV',
#   'bad_ADJ',
#   'restaurant_NOUN',
#   'to_ADP',
#   'us_PRON',
#   '._PUNCT',
#   '\n_SPACE'],
#  ['We_PRON',
#   'stayed_VERB',
#   'here_ADV',
#   'because_ADP',
#   'of_ADP',
#   'all_ADJ',
#   'the_DET',
#   'great_ADJ',
#   'reviews_NOUN',
#   ',_PUNCT',
#   'and_CCONJ',
#   'it_PRON',
#   "'s_VERB",
#   'all_ADV',
#   'true_ADJ',
#   '._PUNCT',
#   'We_PRON',
#   'were_VERB',
#   'highly_ADV',
#   'impressed_ADJ',
#   'with_ADP',
#   'the_DET',
#   'high_ADJ',
#   'quality_NOUN',
#   'of_ADP',
#   'everything_NOUN',
#   ',_PUNCT',
#   'everyone_NOUN',
#   ',_PUNCT',
#   'and_CCONJ',
#   'the_DET',
#   'location_NOUN',
#   '._PUNCT',
#   'Walking_VERB',
#   'distance_NOUN',
#   'to_ADP',
#   'much_ADJ',
#   'of_ADP',
#   'what_NOUN',
#   'Chicago_PROPN',
#   'has_VERB',
#   'to_PART',
#   'offer_VERB',
#   '._PUNCT',
#   'Gibson_PROPN',
#   "'s_PART",
#   'steakhouse_NOUN',
#   'and_CCONJ',
#   'the_DET',
#   'Hancock_PROPN',
#   'building_NOUN',
#   'to_PART',
#   'name_VERB',
#   'a_DET',
#   'couple_NOUN',
#   '._PUNCT',
#   'This_DET',
#   'hotel_NOUN',
#   'should_VERB',
#   'really_ADV',
#   'be_VERB',
#   'in_ADP',
#   'the_DET',
#   'top_ADJ',
#   'ten_NUM',
#   'or_CCONJ',
#   'even_ADV',
#   'top_ADJ',
#   'five_NUM',
#   'hotels_NOUN',
#   'for_ADP',
#   'Chicago_PROPN',
#   '._PUNCT',
#   'It_PRON',
#   'should_VERB',
#   'also_ADV',
#   'have_VERB',
#   'more_ADJ',
#   'than_ADP',
#   'three_NUM',
#   'stars_NOUN',
#   '._PUNCT',
#   'I_PRON',
#   'mean_VERB',
#   'three_NUM',
#   'stars_NOUN',
#   'is_VERB',
#   'for_ADP',
#   'the_DET',
#   'hilton_NOUN',
#   'garden_NOUN',
#   'inn_NOUN',
#   'or_CCONJ',
#   'marriott_NOUN',
#   'courtyard_NOUN',
#   ',_PUNCT',
#   'and_CCONJ',
#   'this_DET',
#   'place_NOUN',
#   'far_ADV',
#   'exceeds_VERB',
#   'chain_NOUN',
#   'hotels_NOUN',
#   'like_ADP',
#   'those_DET',
#   '._PUNCT',
#   'Depending_VERB',
#   'on_ADP',
#   'the_DET',
#   'room_NOUN',
#   'you_PRON',
#   'get_VERB',
#   ',_PUNCT',
#   'any_DET',
#   'price_NOUN',
#   'under_ADP',
#   '$_SYM',
#   '250_NUM',
#   'would_VERB',
#   'be_VERB',
#   'a_DET',
#   'good_ADJ',
#   'deal_NOUN',
#   '._PUNCT',
#   'Between_ADP',
#   '250_NUM',
#   '-_SYM',
#   '300_NUM',
#   'could_VERB',
#   'still_ADV',
#   'be_VERB',
#   'worth_ADJ',
#   'it_PRON',
#   '._PUNCT',
#   '\n_SPACE'],
#  ['Just_ADV',
#   'returned_VERB',
#   'from_ADP',
#   'a_DET',
#   'week_NOUN',
#   'in_ADP',
#   'Chicago_PROPN',
#   'with_ADP',
#   'the_DET',
#   'family_NOUN',
#   '._PUNCT',
#   'This_DET',
#   'hotel_NOUN',
#   'was_VERB',
#   'perfect_ADJ',
#   'for_ADP',
#   'us_PRON',
#   '._PUNCT',
#   'Location_NOUN',
#   'is_VERB',
#   'great_ADJ',
#   ',_PUNCT',
#   'kids_NOUN',
#   'loved_VERB',
#   'the_DET',
#   'pool_NOUN',
#   'as_ADP',
#   'a_DET',
#   'place_NOUN',
#   'to_PART',
#   'wind_VERB',
#   'down_PART',
#   'after_ADP',
#   'a_DET',
#   'day_NOUN',
#   'of_ADP',
#   'museums_NOUN',
#   ',_PUNCT',
#   'touring_VERB',
#   ',_PUNCT',
#   'ball_NOUN',
#   'games_NOUN',
#   ',_PUNCT',
#   'etc_X',
#   '._PUNCT',
#   'We_PRON',
#   'checked_VERB',
#   'in_PART',
#   'through_ADP',
#   'Hilton_PROPN',
#   'Honors_PROPN',
#   'Desk_PROPN',
#   'as_ADP',
#   'opposed_VERB',
#   'to_ADP',
#   'the_DET',
#   'regular_ADJ',
#   'check_NOUN',
#   'in_ADP',
#   'line_NOUN',
#   '._PUNCT',
#   'Even_ADV',
#   'though_ADP',
#   'our_ADJ',
#   'reservations_NOUN',
#   'were_VERB',
#   'through_ADP',
#   'priceline_NOUN',
#   'at_ADP',
#   'a_DET',
#   'reduced_ADJ',
#   'rate_NOUN',
#   ',_PUNCT',
#   'they_PRON',
#   'gave_VERB',
#   'us_PRON',
#   'a_DET',
#   'pick_NOUN',
#   'of_ADP',
#   'the_DET',
#   'the_DET',
#   'rooms_NOUN',
#   '._PUNCT',
#   'The_DET',
#   'room_NOUN',
#   'had_VERB',
#   'a_DET',
#   'large_ADJ',
#   'closet_NOUN',
#   'which_ADJ',
#   'helped_VERB',
#   'with_ADP',
#   'the_DET',
#   'amount_NOUN',
#   'of_ADP',
#   'gear_NOUN',
#   'we_PRON',
#   'had_VERB',
#   'with_ADP',
#   'us_PRON',
#   '._PUNCT',
#   'Used_VERB',
#   'valet_NOUN',
#   'parking_NOUN',
#   'which_ADJ',
#   'was_VERB',
#   'hasselfree_ADJ',
#   '._PUNCT',
#   'We_PRON',
#   'had_VERB',
#   'a_DET',
#   'great_ADJ',
#   'experience_NOUN',
#   'and_CCONJ',
#   'would_VERB',
#   'stay_VERB',
#   'there_ADV',
#   'again_ADV',
#   '._PUNCT',
#   '\n_SPACE'],
#  ['We_PRON',
#   'stayed_VERB',
#   'at_ADP',
#   'the_DET',
#   'Swissotel_PROPN',
#   'for_ADP',
#   'a_DET',
#   'special_ADJ',
#   'birthday_NOUN',
#   'weekend_NOUN',
#   'for_ADP',
#   'my_ADJ',
#   'wife_NOUN',
#   'from_ADP',
#   'Aug_PROPN',
#   '25_NUM',
#   'to_PART',
#   '29_NUM',
#   '._PUNCT',
#   'I_PRON',
#   'had_VERB',
#   'called_VERB',
#   'ahead_ADV',
#   'to_PART',
#   'ask_VERB',
#   'for_ADP',
#   'a_DET',
#   'nice_ADJ',
#   'room_NOUN',
#   'and_CCONJ',
#   'to_PART',
#   'order_VERB',
#   'flowers_NOUN',
#   'for_ADP',
#   'my_ADJ',
#   'wife_NOUN',
#   '._PUNCT',
#   'Jaymes_PROPN',
#   'Ballard_PROPN',
#   ',_PUNCT',
#   'the_DET',
#   'Concierge_PROPN',
#   ',_PUNCT',
#   'made_VERB',
#   'arrange_NOUN',
#   'for_ADP',
#   'flowers_NOUN',
#   ',_PUNCT',
#   'early_ADJ',
#   'check_NOUN',
#   '-_PUNCT',
#   'in_NOUN',
#   'and_CCONJ',
#   'we_PRON',
#   'had_VERB',
#   'a_DET',
#   'great_ADJ',
#   'room_NOUN',
#   '._PUNCT',
#   'Our_ADJ',
#   'room_NOUN',
#   'was_VERB',
#   'the_DET',
#   '33rd_ADJ',
#   'floor_NOUN',
#   'with_ADP',
#   'a_DET',
#   'view_NOUN',
#   'facing_VERB',
#   'the_DET',
#   'city_NOUN',
#   '._PUNCT',
#   'Room_PROPN',
#   'was_VERB',
#   'large_ADJ',
#   ',_PUNCT',
#   'everything_NOUN',
#   'looked_VERB',
#   'like_ADP',
#   'new_ADJ',
#   ',_PUNCT',
#   'great_ADJ',
#   'bed_NOUN',
#   ',_PUNCT',
#   'large_ADJ',
#   'bathroom_NOUN',
#   'with_ADP',
#   'separate_ADJ',
#   'shower_NOUN',
#   ',_PUNCT',
#   'great_ADJ',
#   'ammenities_NOUN',
#   '._PUNCT',
#   'A_DET',
#   'beautiful_ADJ',
#   'bouquet_NOUN',
#   'of_ADP',
#   'flowers_NOUN',
#   'arrived_VERB',
#   'upon_ADP',
#   'our_ADJ',
#   'arrival_NOUN',
#   '._PUNCT',
#   'The_DET',
#   'hotel_NOUN',
#   'is_VERB',
#   'about_ADV',
#   '10_NUM',
#   'mins_NOUN',
#   'from_ADP',
#   'everything_NOUN',
#   ',_PUNCT',
#   'not_ADV',
#   'close_ADJ',
#   'but_CCONJ',
#   'not_ADV',
#   'far_ADV',
#   'from_ADP',
#   'anything_NOUN',
#   '._PUNCT',
#   'Has_VERB',
#   'a_DET',
#   'great_ADJ',
#   'restaurant_NOUN',
#   ',_PUNCT',
#   '2_NUM',
#   'patios_NOUN',
#   'outside_ADV',
#   'where_ADV',
#   'I_PRON',
#   'had_VERB',
#   'a_DET',
#   'cigar_NOUN',
#   '._PUNCT',
#   'A_DET',
#   'really_ADV',
#   'nice_ADJ',
#   'pool_NOUN',
#   'and_CCONJ',
#   'hot_ADJ',
#   'tub_NOUN',
#   'on_ADP',
#   'the_DET',
#   '42nd_ADJ',
#   'floor_NOUN',
#   '._PUNCT',
#   'I_PRON',
#   'would_VERB',
#   'recommend_VERB',
#   'this_DET',
#   'hotel_NOUN',
#   'to_ADP',
#   'anyone_NOUN',
#   'and_CCONJ',
#   'thanks_NOUN',
#   'to_ADP',
#   'Jaymes_PROPN',
#   'for_ADP',
#   'making_VERB',
#   'our_ADJ',
#   'trip_NOUN',
#   'very_ADV',
#   'special_ADJ',
#   '._PUNCT',
#   '\n_SPACE'],
#  ['I_PRON',
#   'just_ADV',
#   'left_VERB',
#   'the_DET',
#   'Conrad_PROPN',
#   'Chicago_PROPN',
#   'and_CCONJ',
#   'have_VERB',
#   'nothing_NOUN',
#   'but_ADP',
#   'good_ADJ',
#   'things_NOUN',
#   'to_PART',
#   'say_VERB',
#   '._PUNCT',
#   'We_PRON',
#   'used_VERB',
#   'Hilton_PROPN',
#   'points_NOUN',
#   'to_PART',
#   'stay_VERB',
#   'there_ADV',
#   'but_CCONJ',
#   'paid_VERB',
#   '$_SYM',
#   '35/night_NUM',
#   'to_PART',
#   'upgrade_VERB',
#   'to_ADP',
#   'a_DET',
#   'junior_ADJ',
#   'suite_NOUN',
#   '._PUNCT',
#   'We_PRON',
#   'were_VERB',
#   'in_ADP',
#   'room_NOUN',
#   '1519_NUM',
#   '._PUNCT',
#   'I_PRON',
#   'would_VERB',
#   'reccomend_VERB',
#   'people_NOUN',
#   'ask_VERB',
#   'for_ADP',
#   'an_DET',
#   'odd_ADJ',
#   'numbered_ADJ',
#   'room_NOUN',
#   'so_ADP',
#   'that_ADP',
#   'they_PRON',
#   'will_VERB',
#   'have_VERB',
#   'a_DET',
#   'view_NOUN',
#   'looking_VERB',
#   'north_ADV',
#   'on_ADP',
#   'Michigan_PROPN',
#   'Ave_PROPN',
#   '._PUNCT',
#   'Our_ADJ',
#   'room_NOUN',
#   'was_VERB',
#   'very_ADV',
#   'modern_ADJ',
#   'with_ADP',
#   '2_NUM',
#   'large_ADJ',
#   'HD_NOUN',
#   '/_SYM',
#   'flat_ADJ',
#   'panel_NOUN',
#   'tv_NOUN',
#   'and_CCONJ',
#   'Bose_PROPN',
#   '3_NUM',
#   'speaker_NOUN',
#   'sound_ADJ',
#   'system_NOUN',
#   '._PUNCT',
#   '4_NUM',
#   'big_ADJ',
#   'windows_NOUN',
#   'that_ADJ',
#   'actually_ADV',
#   'open_ADJ',
#   '._PUNCT',
#   'The_DET',
#   'bed_NOUN',
#   'lineds_NOUN',
#   'were_VERB',
#   'very_ADV',
#   'nice_ADJ',
#   ',_PUNCT',
#   'the_DET',
#   'towels_NOUN',
#   'were_VERB',
#   'OK_ADJ',
#   '._PUNCT',
#   'The_DET',
#   'room_NOUN',
#   'was_VERB',
#   'clean_ADJ',
#   'and_CCONJ',
#   'the_DET',
#   'bath_NOUN',
#   'room_NOUN',
#   'had_VERB',
#   'a_DET',
#   'seperate_ADJ',
#   'shower_NOUN',
#   'and_CCONJ',
#   'tub_NOUN',
#   '._PUNCT',
#   'Marble_PROPN',
#   'everywhere_ADV',
#   '._PUNCT',
#   'Robes_NOUN',
#   ',_PUNCT',
#   'slippers_NOUN',
#   ',_PUNCT',
#   'etc_X',
#   '._PUNCT',
#   'The_DET',
#   'work_NOUN',
#   'out_ADP',
#   'room_NOUN',
#   'was_VERB',
#   'good_ADJ',
#   'with_ADP',
#   'different_ADJ',
#   'machines_NOUN',
#   'and_CCONJ',
#   'some_DET',
#   'free_ADJ',
#   'weights_NOUN',
#   '._PUNCT',
#   'There_ADV',
#   'are_VERB',
#   'clean_ADJ',
#   'towels_NOUN',
#   'in_ADP',
#   'the_DET',
#   'workout_NOUN',
#   'room_NOUN',
#   'too_ADV',
#   '._PUNCT',
#   'We_PRON',
#   'never_ADV',
#   'ate_VERB',
#   'in_ADP',
#   'the_DET',
#   'hotel_NOUN',
#   'so_ADP',
#   'I_PRON',
#   'ca_VERB',
#   "n't_ADV",
#   'comment_VERB',
#   'on_ADP',
#   'the_DET',
#   'food_NOUN',
#   'or_CCONJ',
#   'the_DET',
#   'prices_NOUN',
#   '._PUNCT',
#   'There_ADV',
#   'is_VERB',
#   'a_DET',
#   'Starbucks_PROPN',
#   'across_ADP',
#   'the_DET',
#   'street_NOUN',
#   '(_PUNCT',
#   'Michigan_PROPN',
#   ')_PUNCT',
#   'and_CCONJ',
#   'an_DET',
#   'Espresso_PROPN',
#   'bar_NOUN',
#   'attached_VERB',
#   'to_ADP',
#   'the_DET',
#   'Nordstrom_PROPN',
#   'that_ADJ',
#   'is_VERB',
#   'on_ADP',
#   'the_DET',
#   'ground_NOUN',
#   'floor_NOUN',
#   'of_ADP',
#   'the_DET',
#   'hotel_NOUN',
#   '._PUNCT',
#   'It_PRON',
#   'was_VERB',
#   'very_ADV',
#   'nice_ADJ',
#   'to_PART',
#   'have_VERB',
#   'the_DET',
#   'little_ADJ',
#   'mall_NOUN',
#   'right_ADV',
#   'under_ADP',
#   'the_DET',
#   'hotel_NOUN',
#   '._PUNCT',
#   'The_DET',
#   'location_NOUN',
#   'of_ADP',
#   'the_DET',
#   'hotel_NOUN',
#   'could_VERB',
#   'not_ADV',
#   'be_VERB',
#   'better_ADJ',
#   '._PUNCT',
#   'We_PRON',
#   'were_VERB',
#   'walking_VERB',
#   'distance_NOUN',
#   'to_ADP',
#   'everything_NOUN',
#   '._PUNCT',
#   'Every_DET',
#   'kind_NOUN',
#   'of_ADP',
#   'shopping_NOUN',
#   'or_CCONJ',
#   'dinning_VERB',
#   'experience_NOUN',
#   'you_PRON',
#   'could_VERB',
#   'possibly_ADV',
#   'want_VERB',
#   'was_VERB',
#   'within_ADP',
#   '2_NUM',
#   'miles_NOUN',
#   '._PUNCT',
#   'Over_ADP',
#   'all_ADJ',
#   'the_DET',
#   'hotel_NOUN',
#   'had_VERB',
#   'a_DET',
#   'boutique_NOUN',
#   'feel_VERB',
#   'to_ADP',
#   'it_PRON',
#   'even_ADV',
#   'though_ADP',
#   'it_PRON',
#   'is_VERB',
#   'part_NOUN',
#   'of_ADP',
#   'the_DET',
#   'hilton_NOUN',
#   'chain_NOUN',
#   '._PUNCT',
#   '\n_SPACE'],
#  ['This_DET',
#   'is_VERB',
#   'a_DET',
#   'great_ADJ',
#   'hotel_NOUN',
#   '!_PUNCT',
#   'The_DET',
#   'views_NOUN',
#   'are_VERB',
#   'fabulous_ADJ',
#   ',_PUNCT',
#   'the_DET',
#   'service_NOUN',
#   'it_PRON',
#   'friendly_ADJ',
#   'and_CCONJ',
#   'the_DET',
#   'location_NOUN',
#   'is_VERB',
#   'superb_ADJ',
#   '._PUNCT',
#   'We_PRON',
#   'booked_VERB',
#   'a_DET',
#   'room_NOUN',
#   'on_ADP',
#   'an_DET',
#   'upper_ADJ',
#   'floor_NOUN',
#   'and_CCONJ',
#   'had_VERB',
#   'access_NOUN',
#   'to_ADP',
#   'the_DET',
#   'lounge_NOUN',
#   'where_ADV',
#   'breakfast_NOUN',
#   'and_CCONJ',
#   'snacks_NOUN',
#   'were_VERB',
#   'available_ADJ',
#   'with_ADP',
#   'picture_NOUN',
#   'perfect_ADJ',
#   'views_NOUN',
#   'of_ADP',
#   'the_DET',
#   'Chicago_PROPN',
#   'River_PROPN',
#   '._PUNCT',
#   'The_DET',
#   'only_ADJ',
#   'negative_ADJ',
#   'is_VERB',
#   'that_ADP',
#   'the_DET',
#   'ceilings_NOUN',
#   'in_ADP',
#   'the_DET',
#   'hall_NOUN',
#   'and_CCONJ',
#   'room_NOUN',
#   'are_VERB',
#   'low_ADJ',
#   'and_CCONJ',
#   'can_VERB',
#   'make_VERB',
#   'you_PRON',
#   'feel_VERB',
#   'a_DET',
#   'little_ADJ',
#   'cramped_VERB',
#   '._PUNCT',
#   'We_PRON',
#   'booked_VERB',
#   'our_ADJ',
#   'room_NOUN',
#   'for_ADP',
#   '$_SYM',
#   '89_NUM',
#   'a_DET',
#   'night_NOUN',
#   'for_ADP',
#   'Memorial_PROPN',
#   'Day_PROPN',
#   'weekend_NOUN',
#   '._PUNCT',
#   'It_PRON',
#   'was_VERB',
#   'a_DET',
#   'steal_NOUN',
#   '!_PUNCT',
#   'I_PRON',
#   'highly_ADV',
#   'recommend_VERB',
#   'this_DET',
#   'hotel_NOUN',
#   'to_ADP',
#   'anyone_NOUN',
#   'and_CCONJ',
#   'will_VERB',
#   'be_VERB',
#   'returning_VERB',
#   '!_PUNCT',
#   '\n_SPACE'],
#  ['Got_VERB',
#   'a_DET',
#   'good_ADJ',
#   'deal_NOUN',
#   'on_ADP',
#   'a_DET',
#   'weekend_NOUN',
#   'pacage_NOUN',
#   'in_ADP',
#   'this_DET',
#   'Hotel_PROPN',
#   'and_CCONJ',
#   'have_VERB',
#   'to_PART',
#   'say_VERB',
#   'it_PRON',
#   'is_VERB',
#   'the_DET',
#   'nicest_ADJ',
#   'stay_NOUN',
#   'I_PRON',
#   'have_VERB',
#   'had_VERB',
#   'in_ADP',
#   'more_ADJ',
#   'than_ADP',
#   'a_DET',
#   'dozen_NOUN',
#   'business_NOUN',
#   'trips_NOUN',
#   'to_ADP',
#   'Chicago_PROPN',
#   '._PUNCT',
#   'All_DET',
#   'rooms_NOUN',
#   'are_VERB',
#   'Suites_PROPN',
#   ',_PUNCT',
#   'staff_NOUN',
#   'is_VERB',
#   'friendly_ADJ',
#   'and_CCONJ',
#   'professional_ADJ',
#   ',_PUNCT',
#   'Restaurant_NOUN',
#   'is_VERB',
#   'out_ADP',
#   'of_ADP',
#   'this_DET',
#   'world_NOUN',
#   'and_CCONJ',
#   'all_ADJ',
#   'the_DET',
#   'extras_NOUN',
#   'like_ADP',
#   'a_DET',
#   'great_ADJ',
#   'health_NOUN',
#   'club_NOUN',
#   ',_PUNCT',
#   'turn_VERB',
#   'down_PART',
#   'service_NOUN',
#   ',_PUNCT',
#   'complimentary_ADJ',
#   'morning_NOUN',
#   'beverages_NOUN',
#   'delivered_VERB',
#   'to_PART',
#   'room_VERB',
#   'and_CCONJ',
#   'on_ADV',
#   'and_CCONJ',
#   'on_ADV',
#   '._PUNCT',
#   'Room_PROPN',
#   'was_VERB',
#   'very_ADV',
#   'clean_ADJ',
#   'and_CCONJ',
#   'every_DET',
#   'need_NOUN',
#   'was_VERB',
#   'attended_VERB',
#   'to_ADP',
#   'without_ADP',
#   'feeling_VERB',
#   'intruded_VERB',
#   'on_ADP',
#   '._PUNCT',
#   'Will_VERB',
#   'definately_ADV',
#   'stay_VERB',
#   'here_ADV',
#   'again_ADV',
#   '._PUNCT',
#   '\n_SPACE'],
#  ['Thirty_NUM',
#   'years_NOUN',
#   'ago_ADV',
#   ',_PUNCT',
#   'we_PRON',
#   'had_VERB',
#   'a_DET',
#   'tiny_ADJ',
#   '"_PUNCT',
#   'room_NOUN',
#   '"_PUNCT',
#   'and_CCONJ',
#   'indifferent_ADJ',
#   'service_NOUN',
#   '._PUNCT',
#   'This_DET',
#   'time_NOUN',
#   ',_PUNCT',
#   'the_DET',
#   'service_NOUN',
#   'was_VERB',
#   'superb_ADJ',
#   'and_CCONJ',
#   'friendly_ADJ',
#   'throughout_ADP',
#   ',_PUNCT',
#   'with_ADP',
#   'special_ADJ',
#   'commendation_NOUN',
#   'for_ADP',
#   'the_DET',
#   'waiters_NOUN',
#   'and_CCONJ',
#   'waitresses_NOUN',
#   'at_ADP',
#   'the_DET',
#   'coffee_NOUN',
#   'shop_NOUN',
#   ',_PUNCT',
#   'the_DET',
#   'door_NOUN',
#   'and_CCONJ',
#   'bell_NOUN',
#   'persons_NOUN',
#   ',_PUNCT',
#   'and_CCONJ',
#   'the_DET',
#   'hilton_NOUN',
#   'honors_NOUN',
#   'person_NOUN',
#   'at_ADP',
#   'the_DET',
#   'front_ADJ',
#   'desk_NOUN',
#   '._PUNCT',
#   'They_PRON',
#   'even_ADV',
#   'lowered_VERB',
#   'our_ADJ',
#   'price_NOUN',
#   '(_PUNCT',
#   'to_PART',
#   'moderately_ADV',
#   'high_ADV',
#   ')_PUNCT',
#   'when_ADV',
#   'we_PRON',
#   'inquired_VERB',
#   'a_DET',
#   'few_ADJ',
#   'days_NOUN',
#   'before_ADP',
#   'our_ADJ',
#   'stay_NOUN',
#   '._PUNCT',
#   'When_ADV',
#   'we_PRON',
#   'want_VERB',
#   'to_PART',
#   'stay_VERB',
#   'south_ADV',
#   'of_ADP',
#   'the_DET',
#   'river_NOUN',
#   'downtown_NOUN',
#   ',_PUNCT',
#   'we_PRON',
#   'will_VERB',
#   'be_VERB',
#   'back_ADV',
#   '\n_SPACE']]

# %%
data['review_tokenized'] = pd.Series(col)

# %%
data.head()
# Out:
#                                               review  target  \
# 0  The Hard Rock Hotel Chicago has become my favo...       2
# 1  My wife and I had to stay downtown for event t...       2
# 2  took a weekend trip with my wife. got a great ...       2
# 3  We stayed here because of all the great review...       2
# 4  Just returned from a week in Chicago with the ...       2
#
#                                       species_tokens  \
# 0  ['The', 'Hard', 'Rock', 'Hotel', 'Chicago', 'h...
# 1  ['My', 'wife', 'and', 'I', 'had', 'to', 'stay'...
# 2  ['took', 'a', 'weekend', 'trip', 'with', 'my',...
# 3  ['We', 'stayed', 'here', 'because', 'of', 'all...
# 4  ['Just', 'returned', 'from', 'a', 'week', 'in'...
#
#                                        species_lemma  \
# 0  [the, hard, rock, hotel, chicago, have, become...
# 1  [-PRON-, wife, and, -PRON-, have, to, stay, do...
# 2  [take, a, weekend, trip, with, -PRON-, wife, ....
# 3  [-PRON-, stay, here, because, of, all, the, gr...
# 4  [just, return, from, a, week, in, chicago, wit...
#
#                                          species_pos  \
# 0  [DET, PROPN, PROPN, PROPN, PROPN, VERB, VERB, ...
# 1  [ADJ, NOUN, CCONJ, PRON, VERB, PART, VERB, NOU...
# 2  [VERB, DET, NOUN, NOUN, ADP, ADJ, NOUN, PUNCT,...
# 3  [PRON, VERB, ADV, ADP, ADP, ADJ, DET, ADJ, NOU...
# 4  [ADV, VERB, ADP, DET, NOUN, ADP, PROPN, ADP, D...
#
#                                     review_tokenized
# 0  [The_DET, Hard_PROPN, Rock_PROPN, Hotel_PROPN,...
# 1  [My_ADJ, wife_NOUN, and_CCONJ, I_PRON, had_VER...
# 2  [took_VERB, a_DET, weekend_NOUN, trip_NOUN, wi...
# 3  [We_PRON, stayed_VERB, here_ADV, because_ADP, ...
# 4  [Just_ADV, returned_VERB, from_ADP, a_DET, wee...

# %%
from gensim import matutils,corpora, models

def vectorize_comments(df):
    d = corpora.Dictionary(df["review_tokenized"])
    d.filter_extremes(no_below=2, no_above=1)
    d.compactify()
    corpus = [d.doc2bow(text) for text in df["review_tokenized"]]
    corpus = matutils.corpus2csc(corpus, num_terms=len(d.token2id))
    corpus = corpus.transpose()
    return d, corpus

dictionary,corpus = vectorize_comments(data)
print (corpus.shape)
# Out:
# (1610, 6362)

# %%
def train_rfc(X,y):
    n_estimators = [100]
    min_samples_split = [2]
    min_samples_leaf = [1]
    bootstrap = [True]
    parameters = {'n_estimators': n_estimators, 'min_samples_leaf': min_samples_leaf,
                  'min_samples_split': min_samples_split}
    clf = GridSearchCV(RandomForestClassifier(verbose=1,n_jobs=-1), cv=4, param_grid=parameters)
    clf.fit(X, y)
    return clf

# %%
print(corpus)
# Out:
#   (0, 0)	1.0
#   (0, 1)	2.0
#   (0, 2)	1.0
#   (0, 3)	2.0
#   (0, 4)	1.0
#   (0, 5)	1.0
#   (0, 6)	1.0
#   (0, 7)	2.0
#   (0, 8)	3.0
#   (0, 9)	3.0
#   (0, 10)	3.0
#   (0, 11)	3.0
#   (0, 12)	4.0
#   (0, 13)	1.0
#   (0, 14)	1.0
#   (0, 15)	1.0
#   (0, 16)	1.0
#   (0, 17)	1.0
#   (0, 18)	1.0
#   (0, 19)	1.0
#   (0, 20)	1.0
#   (0, 21)	2.0
#   (0, 22)	1.0
#   (0, 23)	1.0
#   (0, 24)	1.0
#   :	:
#   (1609, 1889)	3.0
#   (1609, 1989)	1.0
#   (1609, 2088)	1.0
#   (1609, 2172)	1.0
#   (1609, 2310)	1.0
#   (1609, 2793)	1.0
#   (1609, 2800)	2.0
#   (1609, 2820)	1.0
#   (1609, 2872)	1.0
#   (1609, 2908)	1.0
#   (1609, 3167)	1.0
#   (1609, 3419)	1.0
#   (1609, 3578)	1.0
#   (1609, 3590)	1.0
#   (1609, 3966)	1.0
#   (1609, 4044)	1.0
#   (1609, 4395)	1.0
#   (1609, 4581)	1.0
#   (1609, 4673)	1.0
#   (1609, 5275)	1.0
#   (1609, 5530)	1.0
#   (1609, 6254)	1.0
#   (1609, 6265)	1.0
#   (1609, 6354)	1.0
#   (1609, 6360)	1.0

# %%
X_train, X_test, y_train, y_test = cross_validation.train_test_split(corpus, data["target"], test_size=0.3, random_state=2016)
rfc_clf = train_rfc(X_train,y_train)
print ("Accuracy of RF on CV sets :{}".format(rfc_clf.best_score_))
# Out:
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    0.3s finished
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    0.3s finished
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    0.3s finished
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    0.3s finished
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    0.1s
# Accuracy of RF on CV sets :0.6921029281277729
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    0.4s finished

# %%
print("Accuracy of RF on test sets is : {}".format(rfc_clf.score(X_test,y_test)))
# Out:
# Accuracy of RF on test sets is : 0.6790890269151139
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:    0.0s finished

# %%
def train_svm(X,y):
    parameters = {'C': [10,15,20,25],'random_state':[0]}
    clf = GridSearchCV(SVC(), cv=4, param_grid=parameters)
    clf.fit(X, y)
    return clf

# %%
svc_clf = train_svm(X_train,y_train)
print("Best accuracy of SVM on CV sets :{}".format(svc_clf.best_score_))
print("Accuracy of SVM on test sets is : {}".format(svc_clf.score(X_test,y_test)))
# Out:
# Best accuracy of SVM on CV sets :0.7551020408163265
# Accuracy of SVM on test sets is : 0.7660455486542443

# %%
def model_test(review):
    a = svc_clf.predict(review)
    if a == 1.0 :
        return('Fake Review (Positive)')
    elif a == 2.0:
        return('True Review (Positive)')
    elif a == 3.0:
        return('True Review (Negative)')
    else :
        return('Fake Review (Negative)')

# %%
for i in X_test:
    print(model_test(i))
# Out:
# Fake Review (Negative)
# True Review (Positive)
# Fake Review (Negative)
# True Review (Positive)
# Fake Review (Negative)
# Fake Review (Negative)
# Fake Review (Positive)
# True Review (Positive)
# Fake Review (Positive)
# True Review (Positive)
# True Review (Negative)
# True Review (Positive)
# True Review (Negative)
# True Review (Positive)
# True Review (Positive)
# Fake Review (Positive)
# True Review (Positive)
# Fake Review (Negative)
# True Review (Positive)
# Fake Review (Negative)
# Fake Review (Negative)
# True Review (Positive)
# Fake Review (Negative)
# True Review (Negative)
# True Review (Positive)
# True Review (Negative)
# True Review (Negative)
# Fake Review (Negative)
# Fake Review (Negative)
# Fake Review (Negative)
# Fake Review (Negative)
# Fake Review (Positive)
# Fake Review (Negative)
# True Review (Negative)
# True Review (Positive)
# True Review (Negative)
# Fake Review (Positive)
# Fake Review (Positive)
# Fake Review (Negative)
# Fake Review (Negative)
# True Review (Positive)
# Fake Review (Positive)
# Fake Review (Positive)
# True Review (Negative)
# True Review (Negative)
# True Review (Negative)
# True Review (Positive)
# Fake Review (Positive)
# True Review (Positive)
# Fake Review (Negative)
# Fake Review (Positive)
# True Review (Negative)
# True Review (Negative)
# Fake Review (Negative)
# Fake Review (Positive)
# Fake Review (Positive)
# Fake Review (Positive)
# Fake Review (Negative)
# True Review (Positive)
# Fake Review (Negative)
# Fake Review (Negative)
# Fake Review (Negative)
# True Review (Positive)
# True Review (Negative)
# True Review (Positive)
# True Review (Negative)
# True Review (Negative)
# Fake Review (Negative)
# Fake Review (Positive)
# True Review (Positive)
# True Review (Positive)
# True Review (Negative)
# True Review (Negative)
# Fake Review (Negative)
# True Review (Negative)
# Fake Review (Positive)
# True Review (Positive)
# Fake Review (Negative)
# Fake Review (Positive)
# True Review (Positive)
# Fake Review (Negative)
# Fake Review (Positive)
# True Review (Positive)
# True Review (Positive)
# True Review (Negative)
# Fake Review (Negative)
# Fake Review (Negative)
# True Review (Positive)
# Fake Review (Positive)
# Fake Review (Positive)
# Fake Review (Negative)
# Fake Review (Negative)
# True Review (Positive)
# Fake Review (Positive)
# True Review (Negative)
# True Review (Positive)
# Fake Review (Positive)
# Fake Review (Negative)
# True Review (Negative)
# Fake Review (Positive)
# Fake Review (Positive)
# Fake Review (Positive)
# True Review (Positive)
# True Review (Positive)
# Fake Review (Negative)
# True Review (Positive)
# Fake Review (Negative)
# True Review (Negative)
# True Review (Negative)
# Fake Review (Positive)
# True Review (Negative)
# Fake Review (Negative)
# True Review (Positive)
# Fake Review (Positive)
# Fake Review (Negative)
# True Review (Positive)
# Fake Review (Positive)
# True Review (Negative)
# Fake Review (Negative)
# True Review (Negative)
# True Review (Positive)
# True Review (Positive)
# True Review (Negative)
# True Review (Negative)
# Fake Review (Negative)
# Fake Review (Positive)
# Fake Review (Negative)
# True Review (Positive)
# Fake Review (Negative)
# True Review (Negative)
# Fake Review (Positive)
# Fake Review (Negative)
# Fake Review (Positive)
# Fake Review (Positive)
# Fake Review (Positive)
# True Review (Positive)
# Fake Review (Positive)
# Fake Review (Negative)
# Fake Review (Positive)
# True Review (Negative)
# Fake Review (Positive)
# True Review (Positive)
# True Review (Positive)
# Fake Review (Positive)
# Fake Review (Negative)
# True Review (Positive)
# True Review (Negative)
# True Review (Positive)
# Fake Review (Positive)
# True Review (Positive)
# Fake Review (Negative)
# Fake Review (Negative)
# Fake Review (Negative)
# True Review (Positive)
# True Review (Positive)
# True Review (Positive)
# True Review (Positive)
# True Review (Positive)
# True Review (Positive)
# Fake Review (Positive)
# True Review (Negative)
# True Review (Positive)
# Fake Review (Positive)
# Fake Review (Negative)
# Fake Review (Positive)
# True Review (Positive)
# True Review (Negative)
# True Review (Negative)
# Fake Review (Negative)
# True Review (Negative)
# True Review (Negative)
# True Review (Positive)
# Fake Review (Negative)
# True Review (Negative)
# Fake Review (Negative)
# Fake Review (Negative)
# True Review (Negative)
# Fake Review (Positive)
# True Review (Negative)
# Fake Review (Positive)
# True Review (Positive)
# True Review (Positive)
# Fake Review (Positive)
# Fake Review (Positive)
# Fake Review (Positive)
# Fake Review (Positive)
# Fake Review (Positive)
# True Review (Negative)
# Fake Review (Negative)
# True Review (Negative)
# Fake Review (Positive)
# True Review (Negative)
# True Review (Negative)
# Fake Review (Negative)
# Fake Review (Positive)
# True Review (Positive)
# Fake Review (Negative)
# Fake Review (Negative)
# True Review (Positive)
# Fake Review (Negative)
# Fake Review (Negative)
# Fake Review (Positive)
# True Review (Positive)
# True Review (Positive)
# Fake Review (Negative)
# Fake Review (Negative)
# Fake Review (Negative)
# Fake Review (Negative)
# Fake Review (Positive)
# True Review (Positive)
# Fake Review (Positive)
# Fake Review (Positive)
# Fake Review (Positive)
# True Review (Negative)
# True Review (Positive)
# True Review (Positive)
# True Review (Positive)
# Fake Review (Positive)
# Fake Review (Positive)
# Fake Review (Positive)
# True Review (Positive)
# Fake Review (Negative)
# Fake Review (Positive)
# Fake Review (Positive)
# True Review (Positive)
# Fake Review (Positive)
# Fake Review (Negative)
# True Review (Positive)
# True Review (Positive)
# True Review (Positive)
# Fake Review (Negative)
# True Review (Negative)
# True Review (Positive)
# Fake Review (Positive)
# True Review (Negative)
# True Review (Positive)
# Fake Review (Positive)
# Fake Review (Positive)
# True Review (Negative)
# True Review (Positive)
# True Review (Negative)
# Fake Review (Negative)
# Fake Review (Negative)
# Fake Review (Negative)
# Fake Review (Negative)
# Fake Review (Positive)
# Fake Review (Negative)
# True Review (Positive)
# Fake Review (Negative)
# Fake Review (Negative)
# True Review (Negative)
# Fake Review (Negative)
# Fake Review (Positive)
# Fake Review (Negative)
# True Review (Positive)
# Fake Review (Positive)
# True Review (Negative)
# True Review (Negative)
# Fake Review (Negative)
# True Review (Positive)
# Fake Review (Negative)
# True Review (Positive)
# True Review (Negative)
# True Review (Positive)
# Fake Review (Negative)
# Fake Review (Positive)
# True Review (Positive)
# True Review (Positive)
# Fake Review (Positive)
# Fake Review (Negative)
# Fake Review (Negative)
# Fake Review (Negative)
# Fake Review (Negative)
# Fake Review (Negative)
# True Review (Positive)
# Fake Review (Negative)
# Fake Review (Positive)
# True Review (Negative)
# True Review (Positive)
# Fake Review (Positive)
# Fake Review (Positive)
# True Review (Negative)
# Fake Review (Positive)
# True Review (Negative)
# Fake Review (Positive)
# Fake Review (Positive)
# Fake Review (Positive)
# True Review (Negative)
# Fake Review (Positive)
# Fake Review (Positive)
# Fake Review (Positive)
# True Review (Positive)
# Fake Review (Positive)
# True Review (Negative)
# Fake Review (Negative)
# True Review (Positive)
# Fake Review (Negative)
# True Review (Negative)
# Fake Review (Positive)
# True Review (Negative)
# Fake Review (Negative)
# Fake Review (Negative)
# True Review (Negative)
# Fake Review (Positive)
# True Review (Positive)
# Fake Review (Positive)
# True Review (Negative)
# Fake Review (Negative)
# Fake Review (Positive)
# True Review (Negative)
# True Review (Negative)
# Fake Review (Positive)
# True Review (Negative)
# Fake Review (Positive)
# True Review (Positive)
# True Review (Positive)
# Fake Review (Positive)
# Fake Review (Negative)
# Fake Review (Positive)
# Fake Review (Positive)
# True Review (Positive)
# True Review (Positive)
# True Review (Positive)
# True Review (Positive)
# True Review (Positive)
# True Review (Negative)
# True Review (Negative)
# True Review (Positive)
# True Review (Positive)
# True Review (Negative)
# Fake Review (Positive)
# Fake Review (Negative)
# Fake Review (Positive)
# Fake Review (Positive)
# Fake Review (Negative)
# Fake Review (Negative)
# Fake Review (Negative)
# Fake Review (Positive)
# Fake Review (Positive)
# True Review (Positive)
# True Review (Negative)
# True Review (Negative)
# Fake Review (Positive)
# True Review (Negative)
# True Review (Negative)
# Fake Review (Positive)
# Fake Review (Negative)
# Fake Review (Positive)
# True Review (Negative)
# True Review (Negative)
# True Review (Negative)
# Fake Review (Positive)
# True Review (Positive)
# Fake Review (Negative)
# Fake Review (Negative)
# Fake Review (Negative)
# True Review (Positive)
# True Review (Positive)
# True Review (Negative)
# True Review (Positive)
# Fake Review (Positive)
# True Review (Negative)
# Fake Review (Negative)
# True Review (Positive)
# Fake Review (Positive)
# Fake Review (Negative)
# Fake Review (Positive)
# Fake Review (Negative)
# True Review (Positive)
# Fake Review (Positive)
# Fake Review (Negative)
# Fake Review (Positive)
# True Review (Negative)
# Fake Review (Positive)
# Fake Review (Negative)
# True Review (Positive)
# Fake Review (Negative)
# True Review (Negative)
# True Review (Negative)
# Fake Review (Negative)
# Fake Review (Positive)
# Fake Review (Positive)
# Fake Review (Positive)
# True Review (Negative)
# True Review (Negative)
# Fake Review (Positive)
# True Review (Positive)
# True Review (Positive)
# Fake Review (Positive)
# True Review (Negative)
# True Review (Negative)
# Fake Review (Negative)
# True Review (Negative)
# True Review (Positive)
# Fake Review (Positive)
# Fake Review (Positive)
# True Review (Positive)
# True Review (Negative)
# Fake Review (Negative)
# Fake Review (Positive)
# Fake Review (Negative)
# True Review (Negative)
# Fake Review (Positive)
# Fake Review (Negative)
# Fake Review (Positive)
# True Review (Negative)
# Fake Review (Negative)
# True Review (Positive)
# True Review (Negative)
# True Review (Positive)
# True Review (Positive)
# Fake Review (Positive)
# True Review (Positive)
# True Review (Negative)
# True Review (Negative)
# Fake Review (Positive)
# Fake Review (Positive)
# True Review (Positive)
# Fake Review (Positive)
# True Review (Negative)
# True Review (Positive)
# True Review (Negative)
# Fake Review (Positive)
# True Review (Positive)
# Fake Review (Negative)
# Fake Review (Negative)
# True Review (Positive)
# True Review (Negative)
# Fake Review (Negative)
# True Review (Positive)
# True Review (Negative)
# True Review (Positive)
# Fake Review (Negative)
# True Review (Negative)
# Fake Review (Positive)
# True Review (Negative)
# Fake Review (Positive)
# True Review (Positive)
# Fake Review (Positive)
# Fake Review (Positive)
# True Review (Positive)
# True Review (Positive)
# Fake Review (Positive)
# True Review (Positive)
# Fake Review (Negative)
# Fake Review (Positive)
# Fake Review (Negative)
# Fake Review (Positive)
# True Review (Negative)
# Fake Review (Negative)
# True Review (Negative)
# Fake Review (Positive)
# True Review (Positive)
# True Review (Negative)
# True Review (Positive)
# True Review (Positive)
# Fake Review (Positive)
# Fake Review (Negative)
# Fake Review (Positive)
# Fake Review (Positive)
# Fake Review (Positive)
# Fake Review (Negative)
# True Review (Negative)
# Fake Review (Negative)
# True Review (Negative)
# Fake Review (Negative)
# Fake Review (Negative)
# True Review (Negative)
# Fake Review (Positive)
# True Review (Positive)
# True Review (Positive)
# True Review (Positive)
# Fake Review (Negative)
# True Review (Negative)
# True Review (Negative)
# Fake Review (Negative)
# Fake Review (Positive)
# Fake Review (Negative)
# True Review (Negative)
# True Review (Positive)
# Fake Review (Positive)
# Fake Review (Positive)
# Fake Review (Positive)
